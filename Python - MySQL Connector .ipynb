# %%
pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 903.8/903.8 kB 1.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### Establishing connection with MySQL

# %%
import mysql.connector as connector

# %%
connection = connector.connect(host = 'localhost', user = 'root', passwd = 'PASSWORD')

# %%
connection

# %% [markdown]
# #### Creating a cursor

# %%
cursor = connection.cursor()

# %% [markdown]
# #### Executing SQL statements using the cursor

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('bigdatabootcamp',),
#  ('bikestore_production',),
#  ('bikestore_sales',),
#  ('class2_db',),
#  ('food_delivery_app',),
#  ('ineuron_sql',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('python_connection',),
#  ('sakila',),
#  ('sql_assignment',),
#  ('stored_procedure_bank',),
#  ('sys',),
#  ('test',),
#  ('world',)]

# %% [markdown]
# #### Creating a database

# %%
cursor.execute("CREATE DATABASE IF NOT EXISTS python_connection")

# %%
cursor.execute("USE python_connection")

# %%
cursor.execute("""CREATE TABLE python_connection.test_table(
                                studentid INT(20),
                                firstname VARCHAR(10),
                                lastname VARCHAR(20),
                                regid INT(20),
                                classname VARCHAR(15))""")

# %%
cursor.execute("SHOW tables")

# %%
cursor.fetchall()
# Out:
# [('test_table',)]

# %% [markdown]
# #### Insert data into the table

# %%
cursor.execute('INSERT INTO test_table VALUES(423423, "SAHEEN", "AHZAN", 2387644, "BIG DATA")')

# %%
cursor.execute('SELECT * FROM test_table')

# %%
cursor.fetchall()
# Out:
# [(423423, 'SAHEEN', 'AHZAN', 2387644, 'BIG DATA')]

# %%
# HERE, when we INSERT data into a table from an external connection, the data wont actually be updated intp the table in MySQL server
# Check from the MySQL Workbench
# TO do it, we have to commit from out external connection

connection.commit()

# Now check from the Workbecnch and you could see that the data is now inserted in the table

# %%
cursor.execute('INSERT INTO test_table VALUES (423423, "Fathi", "Ashraf", 2387354, "BSAD"), (423422, "Aflah", "Abrar", 2382444, "FSDS"), (424422, "Hiza", "Rawt", 2342444, "FSDA")')

# %%
connection.commit()

# %%
cursor.execute('SELECT * FROM test_table')

# %%
cursor.fetchall()
# Out:
# [(423423, 'SAHEEN', 'AHZAN', 2387644, 'BIG DATA'),
#  (423423, 'Fathi', 'Ashraf', 2387354, 'BSAD'),
#  (423422, 'Aflah', 'Abrar', 2382444, 'FSDS'),
#  (424422, 'Hiza', 'Rawt', 2342444, 'FSDA')]

# %% [markdown]
# #### Uploading data from a csv file to a table

# %%
cursor.execute("""CREATE TABLE admissions(
                    Serial_No INT(3),
                    GRE_Score INT(10),
                    TOEFL_Score INT(10),
                    University_Rating INT(10),
                    SOP FLOAT(10,2),
                    LOR FLOAT(10,2),
                    CGPA FLOAT(10,2),
                    Research INT(10),
                    Chance_of_Admit FLOAT(10,2))""")

# %%
cursor.execute('SHOW TABLES')

# %%
cursor.fetchall()
# Out:
# [('admissions',), ('test_table',)]

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 0AF0-D510
#
#  Directory of c:\Users\sahee\OneDrive\Desktop\Repositories\Working-with-Databases-using-Python
#
# 05/16/2023  07:32 PM    <DIR>          .
# 05/16/2023  07:32 PM    <DIR>          ..
# 05/16/2023  07:32 PM             5,583 Python - MySQL Connector .ipynb
# 05/16/2023  07:28 PM                22 requirements.txt
#                2 File(s)          5,605 bytes
#                2 Dir(s)  125,938,774,016 bytes free

# %%
file = open("Admissions Data.csv", 'r')

# %%
file.read()
# Out:
# '1,337,118,4,4.5,4.5,9.65,1,0.92\n2,324,107,4,4,4.5,8.87,1,0.76\n3,316,104,3,3,3.5,8,1,0.72\n4,322,110,3,3.5,2.5,8.67,1,0.8\n5,314,103,2,2,3,8.21,0,0.65\n6,330,115,5,4.5,3,9.34,1,0.9\n7,321,109,3,3,4,8.2,1,0.75\n8,308,101,2,3,4,7.9,0,0.68\n9,302,102,1,2,1.5,8,0,0.5\n10,323,108,3,3.5,3,8.6,0,0.45\n11,325,106,3,3.5,4,8.4,1,0.52\n12,327,111,4,4,4.5,9,1,0.84\n13,328,112,4,4,4.5,9.1,1,0.78\n14,307,109,3,4,3,8,1,0.62\n15,311,104,3,3.5,2,8.2,1,0.61\n16,314,105,3,3.5,2.5,8.3,0,0.54\n17,317,107,3,4,3,8.7,0,0.66\n18,319,106,3,4,3,8,1,0.65\n19,318,110,3,4,3,8.8,0,0.63\n20,303,102,3,3.5,3,8.5,0,0.62\n21,312,107,3,3,2,7.9,1,0.64\n22,325,114,4,3,2,8.4,0,0.7\n23,328,116,5,5,5,9.5,1,0.94\n24,334,119,5,5,4.5,9.7,1,0.95\n25,336,119,5,4,3.5,9.8,1,0.97\n26,340,120,5,4.5,4.5,9.6,1,0.94\n27,322,109,5,4.5,3.5,8.8,0,0.76\n28,298,98,2,1.5,2.5,7.5,1,0.44\n29,295,93,1,2,2,7.2,0,0.46\n30,310,99,2,1.5,2,7.3,0,0.54\n31,300,97,2,3,3,8.1,1,0.65\n32,327,103,3,4,4,8.3,1,0.74\n33,338,118,4,3,4.5,9.4,1,0.91\n34,340,114
# ...

# %%
import csv

with open("Admissions Data.csv", 'r') as f:
    reader = csv.reader(f, delimiter='\n')
    print(reader)

# %%
import csv

with open("Admissions Data.csv", 'r') as f:
    reader = csv.reader(f, delimiter='\n')
    for i in reader:
        print(i)
# Out:
# ['1,337,118,4,4.5,4.5,9.65,1,0.92']
# ['2,324,107,4,4,4.5,8.87,1,0.76']
# ['3,316,104,3,3,3.5,8,1,0.72']
# ['4,322,110,3,3.5,2.5,8.67,1,0.8']
# ['5,314,103,2,2,3,8.21,0,0.65']
# ['6,330,115,5,4.5,3,9.34,1,0.9']
# ['7,321,109,3,3,4,8.2,1,0.75']
# ['8,308,101,2,3,4,7.9,0,0.68']
# ['9,302,102,1,2,1.5,8,0,0.5']
# ['10,323,108,3,3.5,3,8.6,0,0.45']
# ['11,325,106,3,3.5,4,8.4,1,0.52']
# ['12,327,111,4,4,4.5,9,1,0.84']
# ['13,328,112,4,4,4.5,9.1,1,0.78']
# ['14,307,109,3,4,3,8,1,0.62']
# ['15,311,104,3,3.5,2,8.2,1,0.61']
# ['16,314,105,3,3.5,2.5,8.3,0,0.54']
# ['17,317,107,3,4,3,8.7,0,0.66']
# ['18,319,106,3,4,3,8,1,0.65']
# ['19,318,110,3,4,3,8.8,0,0.63']
# ['20,303,102,3,3.5,3,8.5,0,0.62']
# ['21,312,107,3,3,2,7.9,1,0.64']
# ['22,325,114,4,3,2,8.4,0,0.7']
# ['23,328,116,5,5,5,9.5,1,0.94']
# ['24,334,119,5,5,4.5,9.7,1,0.95']
# ['25,336,119,5,4,3.5,9.8,1,0.97']
# ['26,340,120,5,4.5,4.5,9.6,1,0.94']
# ['27,322,109,5,4.5,3.5,8.8,0,0.76']
# ['28,298,98,2,1.5,2.5,7.5,1,0.44']
# ...

# %%
import csv

with open("Admissions Data.csv", 'r') as f:
    reader = csv.reader(f, delimiter='\n')
    for i in reader:
        print(i[0])
# Out:
# 1,337,118,4,4.5,4.5,9.65,1,0.92
# 2,324,107,4,4,4.5,8.87,1,0.76
# 3,316,104,3,3,3.5,8,1,0.72
# 4,322,110,3,3.5,2.5,8.67,1,0.8
# 5,314,103,2,2,3,8.21,0,0.65
# 6,330,115,5,4.5,3,9.34,1,0.9
# 7,321,109,3,3,4,8.2,1,0.75
# 8,308,101,2,3,4,7.9,0,0.68
# 9,302,102,1,2,1.5,8,0,0.5
# 10,323,108,3,3.5,3,8.6,0,0.45
# 11,325,106,3,3.5,4,8.4,1,0.52
# 12,327,111,4,4,4.5,9,1,0.84
# 13,328,112,4,4,4.5,9.1,1,0.78
# 14,307,109,3,4,3,8,1,0.62
# 15,311,104,3,3.5,2,8.2,1,0.61
# 16,314,105,3,3.5,2.5,8.3,0,0.54
# 17,317,107,3,4,3,8.7,0,0.66
# 18,319,106,3,4,3,8,1,0.65
# 19,318,110,3,4,3,8.8,0,0.63
# 20,303,102,3,3.5,3,8.5,0,0.62
# 21,312,107,3,3,2,7.9,1,0.64
# 22,325,114,4,3,2,8.4,0,0.7
# 23,328,116,5,5,5,9.5,1,0.94
# 24,334,119,5,5,4.5,9.7,1,0.95
# 25,336,119,5,4,3.5,9.8,1,0.97
# 26,340,120,5,4.5,4.5,9.6,1,0.94
# 27,322,109,5,4.5,3.5,8.8,0,0.76
# 28,298,98,2,1.5,2.5,7.5,1,0.44
# 29,295,93,1,2,2,7.2,0,0.46
# 30,310,99,2,1.5,2,7.3,0,0.54
# 31,300,97,2,3,3,8.1,1,0.65
# 32,327,103,3,4,4,8.3,1,0.74
# ...

# %%
# INSERTING THE ABOVE RECORDS INTO THE TABLE

import csv

with open("Admissions Data.csv", 'r') as f:
    reader = csv.reader(f, delimiter='\n')
    for i in reader:
        print(i)
        print(f'INSERT INTO admissions VALUES ({(i[0])})')
        cursor.execute(f'INSERT INTO admissions VALUES ({(i[0])})') 
connection.commit()
# Out:
# ['1,337,118,4,4.5,4.5,9.65,1,0.92']
# INSERT INTO admissions VALUES (1,337,118,4,4.5,4.5,9.65,1,0.92)
# ['2,324,107,4,4,4.5,8.87,1,0.76']
# INSERT INTO admissions VALUES (2,324,107,4,4,4.5,8.87,1,0.76)
# ['3,316,104,3,3,3.5,8,1,0.72']
# INSERT INTO admissions VALUES (3,316,104,3,3,3.5,8,1,0.72)
# ['4,322,110,3,3.5,2.5,8.67,1,0.8']
# INSERT INTO admissions VALUES (4,322,110,3,3.5,2.5,8.67,1,0.8)
# ['5,314,103,2,2,3,8.21,0,0.65']
# INSERT INTO admissions VALUES (5,314,103,2,2,3,8.21,0,0.65)
# ['6,330,115,5,4.5,3,9.34,1,0.9']
# INSERT INTO admissions VALUES (6,330,115,5,4.5,3,9.34,1,0.9)
# ['7,321,109,3,3,4,8.2,1,0.75']
# INSERT INTO admissions VALUES (7,321,109,3,3,4,8.2,1,0.75)
# ['8,308,101,2,3,4,7.9,0,0.68']
# INSERT INTO admissions VALUES (8,308,101,2,3,4,7.9,0,0.68)
# ['9,302,102,1,2,1.5,8,0,0.5']
# INSERT INTO admissions VALUES (9,302,102,1,2,1.5,8,0,0.5)
# ['10,323,108,3,3.5,3,8.6,0,0.45']
# INSERT INTO admissions VALUES (10,323,108,3,3.5,3,8.6,0,0.45)
# ...

# %%
cursor.execute('SELECT * FROM admissions')

# %%
cursor.fetchall()
# Out:
# [(1, 337, 118, 4, 4.5, 4.5, 9.65, 1, 0.92),
#  (2, 324, 107, 4, 4.0, 4.5, 8.87, 1, 0.76),
#  (3, 316, 104, 3, 3.0, 3.5, 8.0, 1, 0.72),
#  (4, 322, 110, 3, 3.5, 2.5, 8.67, 1, 0.8),
#  (5, 314, 103, 2, 2.0, 3.0, 8.21, 0, 0.65),
#  (6, 330, 115, 5, 4.5, 3.0, 9.34, 1, 0.9),
#  (7, 321, 109, 3, 3.0, 4.0, 8.2, 1, 0.75),
#  (8, 308, 101, 2, 3.0, 4.0, 7.9, 0, 0.68),
#  (9, 302, 102, 1, 2.0, 1.5, 8.0, 0, 0.5),
#  (10, 323, 108, 3, 3.5, 3.0, 8.6, 0, 0.45),
#  (11, 325, 106, 3, 3.5, 4.0, 8.4, 1, 0.52),
#  (12, 327, 111, 4, 4.0, 4.5, 9.0, 1, 0.84),
#  (13, 328, 112, 4, 4.0, 4.5, 9.1, 1, 0.78),
#  (14, 307, 109, 3, 4.0, 3.0, 8.0, 1, 0.62),
#  (15, 311, 104, 3, 3.5, 2.0, 8.2, 1, 0.61),
#  (16, 314, 105, 3, 3.5, 2.5, 8.3, 0, 0.54),
#  (17, 317, 107, 3, 4.0, 3.0, 8.7, 0, 0.66),
#  (18, 319, 106, 3, 4.0, 3.0, 8.0, 1, 0.65),
#  (19, 318, 110, 3, 4.0, 3.0, 8.8, 0, 0.63),
#  (20, 303, 102, 3, 3.5, 3.0, 8.5, 0, 0.62),
#  (21, 312, 107, 3, 3.0, 2.0, 7.9, 1, 0.64),
# ...

# %%
# The data from the csv has been successfully read and inserted into the table admissions

# %% [markdown]
# #### Closing the opened connection with MySQL

# %%
connection.close()
